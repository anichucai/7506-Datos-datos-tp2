# %%
import pandas as pd
import numpy as np
from scipy import sparse

from nltk.stem import WordNetLemmatizer

from sklearn.pipeline import Pipeline, make_pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import roc_auc_score
from sklearn import datasets
from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn import metrics

# %%
train = pd.read_csv("csv_lio/train_clean.csv")
test  = pd.read_csv("csv_lio/test_clean.csv")
train = train.drop(columns = 'Unnamed: 0')
test  = test.drop(columns = 'Unnamed: 0')

# %% [markdown]
# ## Split of the train set

# %%
X = train.text.values.astype('U')
y = train.target.values.astype('U')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)

# %% [markdown]
# ## Extracting features from text files

# %%
# BOW is created (key:value) - word occurrance
# "key" is a specific word
# The index value of a word in the vocabulary is linked to its frequency in the whole training corpus.
count_vect = CountVectorizer(analyzer='word',binary=True)
X_train_counts = count_vect.fit_transform(X_train) #.values.astype('U'))
X_train_counts.shape
# Out:
# (6090, 16309)

# %%
# TF-IDF
tfidf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (6090, 16309)

# %% [markdown]
# ## Training a classifier - no pipeline

# %%
# Multinomial Naive Bayes
# y_train :  es la columna target
# X_train_tfidf : es el campo "text" entrenado
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
X_test_counts = count_vect.transform(X_test)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)

predicted = clf.predict(X_test_tfidf)

# %%
print(len(predicted))
# Out:
# 1523

# %%
# imprimimos las predicciones para el X_test
for tweet, category in zip(X_test, predicted):
    print('%r => %s' % (tweet, y_train))
# Out:
# '   fouseytube -PRON- ambulance hahahah zsberqnn' => ['0' '0' '0' ... '1' '1' '0']
# '   jusstdoitgirl -PRON- shit tryna trouble wbu homie' => ['0' '0' '0' ... '1' '1' '0']
# '   bovine rescue smuggler nab fn ruu' => ['0' '0' '0' ... '1' '1' '0']
# ' storm fuck -PRON- -PRON- cool' => ['0' '0' '0' ... '1' '1' '0']
# '   abc parent colorado theater shoot victim fear copycat massacre lvlh awo antioch viwxy xdyk' => ['0' '0' '0' ... '1' '1' '0']
# ' join providence health team -PRON- nursing hzemldpu torrance hire' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- engulf image quiz cimubweyib fst bd' => ['0' '0' '0' ... '1' '1' '0']
# ' loner diarie pattern sand blow photo choke flame ekfaz wvbz' => ['0' '0' '0' ... '1' '1' '0']
# ' drive dust storm sruj zljgl' => ['0' '0' '0' ... '1' '1' '0']
# ' emergency unit simulate chemical explosion nu evanston kfyebhb' => ['0' '0' '0' ... '1' '1' '0']
# ' fire truck parking' => ['0' '0' '0' ... '1' '1' '0']
# ' ra message condolence vietnam natural disaster behalf cuban government emrzicb' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- austinpearcy bad -PRON- funny drown -PRON- kiss' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- flame' => ['0' '0' '0' ... '1' '1' '0']
# ' usgs eq volcano hawaii utc rrght ewp earthquake' => ['0' '0' '0' ... '1' '1' '0']
# ' update rockyfire map mandatory evacuation red advisory evacuation yellow evac center green gzegjoakkw' => ['0' '0' '0' ... '1' '1' '0']
# ' kach belong baruch goldstein mass murderer shoot kill palestinian bxgnq xvb' => ['0' '0' '0' ... '1' '1' '0']
# '   jyheffect -PRON- -PRON- ny' => ['0' '0' '0' ... '1' '1' '0']
# '   replace fear unknown curiosity -PRON- -PRON- qrhng kj' => ['0' '0' '0' ... '1' '1' '0']
# ' hibernate pbx irrespective pitch fatality careerism pan crbzfz' => ['0' '0' '0' ... '1' '1' '0']
# '   robertmeyer -PRON- food price farmer broke famine capitalism fail feed people gt' => ['0' '0' '0' ... '1' '1' '0']
# ' amazin -PRON- crazy niggas dey blaze -PRON- hate -PRON- -PRON- -PRON- dedication motivation' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- rescue -PRON- sweep -PRON- sin -PRON- cloud isaiah version' => ['0' '0' '0' ... '1' '1' '0']
# ' photo rescue migrant await disembarkment irish naval vessel palermo italy tconnellyr aim cyhl' => ['0' '0' '0' ... '1' '1' '0']
# '   wearethenew support cosponsor support sick injure responder renew health' => ['0' '0' '0' ... '1' '1' '0']
# '   kaiseiw people -PRON- -PRON- people desolation' => ['0' '0' '0' ... '1' '1' '0']
# ' las vegas city red light fatalities lv exdbcx gcr' => ['0' '0' '0' ... '1' '1' '0']
# ' rt kurtkamka beautiful desolation -PRON- couple coyote lizard morning sun phoenix ariz pvjvdpf' => ['0' '0' '0' ... '1' '1' '0']
# '   madhya pradesh train derailment village youth fctrawjcyl ndtv' => ['0' '0' '0' ... '1' '1' '0']
# ' obliterated' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- land engulf tribal war -PRON- land peace madinah prophetmuhammad islam' => ['0' '0' '0' ... '1' '1' '0']
# ' squeeze -PRON- bare hand -PRON- literally explode' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- -PRON- ship airplane accident terrible' => ['0' '0' '0' ... '1' '1' '0']
# ' neighbor kid -PRON- disney lava -PRON- -PRON- uke leave journey kidstheseday' => ['0' '0' '0' ... '1' '1' '0']
# ' literally trap -PRON- cuz -PRON- bathroom remodel exit window' => ['0' '0' '0' ... '1' '1' '0']
# '   nuke target hilversum detonate meter surface' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- electrocute -PRON- -PRON- charge' => ['0' '0' '0' ... '1' '1' '0']
# ' fuck loud bang flash light pretty dead hell' => ['0' '0' '0' ... '1' '1' '0']
# ' molecularly target cancer therapy -PRON- lungcancer rocky -PRON- twi pym -PRON- qt jmd pi' => ['0' '0' '0' ... '1' '1' '0']
# '   blow oomf instagram -PRON- cute -PRON- active follower' => ['0' '0' '0' ... '1' '1' '0']
# '   xjkrxrnwnv flooding track derailment sa insubcontinent insubcontinent jlwgshyy' => ['0' '0' '0' ... '1' '1' '0']
# '   akcsl venture music mayhem' => ['0' '0' '0' ... '1' '1' '0']
# ' sandstorm efkcoegjck' => ['0' '0' '0' ... '1' '1' '0']
# ' meltdown becca caitlyn leave lucky blessed' => ['0' '0' '0' ... '1' '1' '0']
# ' green derailment -PRON- concern track cta ctafails udz nvoeh' => ['0' '0' '0' ... '1' '1' '0']
# '   settlement attain -PRON- illustration juror devastation internal injury baxg wdpp' => ['0' '0' '0' ... '1' '1' '0']
# ' link reddit content policy horrible subreddit ban quarantine bjvfk ete' => ['0' '0' '0' ... '1' '1' '0']
# '   mentalhealthgov ahhhhh alec med tort comp law lead injustice -PRON- mh qejedwsfdg' => ['0' '0' '0' ... '1' '1' '0']
# '   daborsch shocking blizzard lure -PRON- fanbase wod disappoint -PRON- hardcore leave' => ['0' '0' '0' ... '1' '1' '0']
# ' elem pomo displace rocky fire elem evacuation center dydfvz amj gofundme' => ['0' '0' '0' ... '1' '1' '0']
# '   abcnew obama declare disaster typhoon devastate saipan obama sign disaster declaration dobzc pitm' => ['0' '0' '0' ... '1' '1' '0']
# '   marcoarment middle winter sydney -PRON- snow bush fire degree -PRON- -PRON- toe' => ['0' '0' '0' ... '1' '1' '0']
# ' chevrolet avalanche lt lt automatic wd pickup truck premium obky pc dxirntdsrd' => ['0' '0' '0' ... '1' '1' '0']
# ' triumphant moment -PRON- cook egg yolk casualty fqj aga pd' => ['0' '0' '0' ... '1' '1' '0']
# ' kid disappear dust storm atmospheric aussie thriller mnpcer rt newz sacramento' => ['0' '0' '0' ... '1' '1' '0']
# ' pussy deep drown' => ['0' '0' '0' ... '1' '1' '0']
# ' crazy throw teen daughter nude twister sex accord -PRON- friend lnfwf rocyyei dm' => ['0' '0' '0' ... '1' '1' '0']
# ' beautiful lightning plane window cwuylnfum tyyqfz' => ['0' '0' '0' ... '1' '1' '0']
# '   mh aircraft debris reunion malaysia airlines hhwv eudfv' => ['0' '0' '0' ... '1' '1' '0']
# '   charlesadler ian lee word fart windstorm browner' => ['0' '0' '0' ... '1' '1' '0']
# '   habbo bring snowstorm tic tac toe battleship fast food matchwood' => ['0' '0' '0' ... '1' '1' '0']
# ' people truth -PRON- -PRON- illusion destroy fn' => ['0' '0' '0' ... '1' '1' '0']
# '   tweetinglew tersestuff notley flatten harper -PRON- heartland harper import tfw slave cost albertan' => ['0' '0' '0' ... '1' '1' '0']
# '   bomb iran kinder gvm bpm' => ['0' '0' '0' ... '1' '1' '0']
# '   broseidonrex dapurplesharpie skim body bag' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- picture building burn ground basement streetlight -PRON- drinking hole sky' => ['0' '0' '0' ... '1' '1' '0']
# ' afloat pension plan sink ceeuzwhvf' => ['0' '0' '0' ... '1' '1' '0']
# ' sewer -PRON- sink -PRON- pre sinkhole insane heiekfchdm' => ['0' '0' '0' ... '1' '1' '0']
# ' love chicago -PRON- -PRON- pink eye sit design quarantine dark' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- quiet -PRON- literally phandom scream tyler' => ['0' '0' '0' ... '1' '1' '0']
# ' ice cream cupcake wars storm content sara' => ['0' '0' '0' ... '1' '1' '0']
# '   kasiakosek drive suck -PRON- -PRON- desk war zone mode' => ['0' '0' '0' ... '1' '1' '0']
# ' airport swallow sandstorm minute bgm csrbvd' => ['0' '0' '0' ... '1' '1' '0']
# ' police chief assure crowd officer shooting kmxzho tfm albvdnwjtg' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- beat armageddon hsu hao flawless -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' domestic terrorism -PRON- -PRON- create gop hfgjgfgfel' => ['0' '0' '0' ... '1' '1' '0']
# ' police walk -PRON- blowin smoke dey lock -PRON- cus dope shit gay' => ['0' '0' '0' ... '1' '1' '0']
# ' womens flower print shoulder handbag cross body metal chain satchel bag blue rjzw asx wtdiav ua' => ['0' '0' '0' ... '1' '1' '0']
# ' raffi rc rt sustainourearth oklahoma limit earthquake risk oil gas scoopit yru nphdrf love thi' => ['0' '0' '0' ... '1' '1' '0']
# '   dangerous property downtown phoenix demolish hibdw ja' => ['0' '0' '0' ... '1' '1' '0']
# ' fresh da shower lookss love -PRON- ruin -PRON- brand kk fya' => ['0' '0' '0' ... '1' '1' '0']
# '   people -PRON- charge inevitable rioting contribute -PRON- -PRON- lie' => ['0' '0' '0' ... '1' '1' '0']
# ' shadow holdin -PRON- hostage' => ['0' '0' '0' ... '1' '1' '0']
# ' budget trouble agree varagesale candace dx' => ['0' '0' '0' ... '1' '1' '0']
# ' richmond police officer wound suspect kill elimzi' => ['0' '0' '0' ... '1' '1' '0']
# '   realdonaldtrump rushlimbaugh -PRON- proof democrat afraid trump clinton derail trump meddling' => ['0' '0' '0' ... '1' '1' '0']
# ' crazy lightning' => ['0' '0' '0' ... '1' '1' '0']
# ' hail caesars gzmoblsjxu cgtqfk ur' => ['0' '0' '0' ... '1' '1' '0']
# ' rt thr rt thrarchive leo mgm lion survive plane crash tbt wpkl qniqw bd fxdvhq' => ['0' '0' '0' ... '1' '1' '0']
# '   bride groom mountain cliff edge ha ha kid ha ha io ry akon' => ['0' '0' '0' ... '1' '1' '0']
# 'nan' => ['0' '0' '0' ... '1' '1' '0']
# '   youngheroesid lava blast dan power red pantherattack mirmanda evaaasr' => ['0' '0' '0' ... '1' '1' '0']
# ' tropical storm guillermo hawaiianpaddlesports lgpgajgomy fkd mbtb' => ['0' '0' '0' ... '1' '1' '0']
# ' missionhill -PRON- zsnsar tw nursing hire' => ['0' '0' '0' ... '1' '1' '0']
# '   macbreck -PRON- -PRON- obliterate chance win election pre bad math' => ['0' '0' '0' ... '1' '1' '0']
# ' drown -PRON- mustard lemon pepper' => ['0' '0' '0' ... '1' '1' '0']
# ' deal avalanche music purchase neal rigga shirt virxkgmpc' => ['0' '0' '0' ... '1' '1' '0']
# ' family sue legionnaire family affect fatal outbreak legionnaire disea mwc ywjzy' => ['0' '0' '0' ... '1' '1' '0']
# ' rt ophiuchus love truelove romance lith voodoo seduction astrology rtrrt lotz apocalypse armageddon pla' => ['0' '0' '0' ... '1' '1' '0']
# ' evening sun article nno cmf noync' => ['0' '0' '0' ... '1' '1' '0']
# ' horrible sink feeling -PRON- -PRON- -PRON- realise -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   brave dog rescue river -PRON- recovery inspi jywfygclhm' => ['0' '0' '0' ... '1' '1' '0']
# ' wa smile july deluge west australian yi nuovbv yahoo' => ['0' '0' '0' ... '1' '1' '0']
# ' russian food crematoria provoke outrage crisis famine memories sgecnkfthu' => ['0' '0' '0' ... '1' '1' '0']
# '   funkflex yo flex -PRON- azxdlcxga' => ['0' '0' '0' ... '1' '1' '0']
# '   burn ticket vehicle pass ebay es ziork juiit yfvo' => ['0' '0' '0' ... '1' '1' '0']
# ' fuck music extremely loud tuesday morning bruv -PRON- -PRON- bang -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   nigeria suicide bomb attack kill people blame boko haram times cdkpsdfp' => ['0' '0' '0' ... '1' '1' '0']
# '   thomashcrown -PRON- grandfather marines hit japan operation olympic casualty rate prediction' => ['0' '0' '0' ... '1' '1' '0']
# '   japan marks anniversary hiroshima atomic bombing qreinwg gs' => ['0' '0' '0' ... '1' '1' '0']
# ' rescuer -PRON- -PRON- barely alive -PRON- idea -PRON- allergic vecmsiuuh' => ['0' '0' '0' ... '1' '1' '0']
# '   wkrn parent colorado theater shoot victim fear copycat massacre lvlh awo antioch viwxy xdyk' => ['0' '0' '0' ... '1' '1' '0']
# ' trouble rotation leave lean red black tree -PRON- class learni wgl lubnw' => ['0' '0' '0' ... '1' '1' '0']
# ' firefigther evacuate northampton township house fire hppld jhtz' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- mess -PRON- feeling hurricane damage break' => ['0' '0' '0' ... '1' '1' '0']
# '   worldnew fall powerline link tram update fire crew evacuate passenger tr eysvvza qm' => ['0' '0' '0' ... '1' '1' '0']
# '   marvel dccomics imagecomic darkhorsecomic idwpublishe -PRON- enable collapse industry' => ['0' '0' '0' ... '1' '1' '0']
# '   grupdate pkk suicide bomber detonate bomb turkey army trench release gt fqcdphccg' => ['0' '0' '0' ... '1' '1' '0']
# ' forestservice rt dhsscitech firefighter burn building -PRON- kybqcsvrza ih kymsmp' => ['0' '0' '0' ... '1' '1' '0']
# ' update rly -PRON- -PRON- scream vibrate handle' => ['0' '0' '0' ... '1' '1' '0']
# '   explosion begforcum allday cumshots cumcovere sexycumshot cumtown bj nutt cumslut girlslovecum cx yjjoz' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- fam evacuate bc -PRON- power' => ['0' '0' '0' ... '1' '1' '0']
# '   break tasmania emergency train horse urjwsvr jfreteii' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- hazardous alive bjzssw tid' => ['0' '0' '0' ... '1' '1' '0']
# '   ymcglaun juliekragt wildwestsixgun -PRON- safe stable trouble seat' => ['0' '0' '0' ... '1' '1' '0']
# ' stupid woman collide -PRON- -PRON- junction -PRON- beep -PRON- horn' => ['0' '0' '0' ... '1' '1' '0']
# '   itsmegss -PRON- -PRON- bloody barking' => ['0' '0' '0' ... '1' '1' '0']
# ' couple sex fear -PRON- internet movie sex xhizprad' => ['0' '0' '0' ... '1' '1' '0']
# '   gunsense answer gfz break law minuscule chance mass murderer qeopmcjbcz' => ['0' '0' '0' ... '1' '1' '0']
# ' precious cargo onesie recall choke hazard pamznyyuw' => ['0' '0' '0' ... '1' '1' '0']
# ' hiroshima survivor fight nuclear industry brazil shtylbnl' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- escape -PRON- bullet harm -PRON- harm -PRON- pain pain share -PRON- -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- pull fight hoe zayn terrorist fy fv qbx' => ['0' '0' '0' ... '1' '1' '0']
# ' block plate charge schwarber cervelli -PRON- -PRON- explode puff smoke' => ['0' '0' '0' ... '1' '1' '0']
# '   amateur actress reprise siren horrormovies horror cd offcj' => ['0' '0' '0' ... '1' '1' '0']
# '   christinalavv lindsay wynn attack' => ['0' '0' '0' ... '1' '1' '0']
# '   snapharmony bell toll hiroshima japan marks atomic bombing ypvvqz jzt' => ['0' '0' '0' ... '1' '1' '0']
# ' photo scare leave -PRON- tree storm jamaicaplain boston hailstorm fhrrhcimh' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- band building fire bbcintroduce purpleturtlerdg wednesday giantgiantsound ofan dkoez rdg' => ['0' '0' '0' ... '1' '1' '0']
# ' suicide bomber kill saudi mosque bhb xt' => ['0' '0' '0' ... '1' '1' '0']
# ' classic hiroshima nagasaki atomic devastation hide decade people hiroshima nagasaki plo qkrwhu' => ['0' '0' '0' ... '1' '1' '0']
# ' cam demolish -PRON- plate -PRON- ass hungry' => ['0' '0' '0' ... '1' '1' '0']
# ' mad max screenshot lovely dust storm combat magnum opus cmaqf ns' => ['0' '0' '0' ... '1' '1' '0']
# ' fedex transport bioterror germ wake anthrax lab mishap xtezgjfs' => ['0' '0' '0' ... '1' '1' '0']
# ' court session testimony continue med examiner gunshot wound kerricktrial' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- favorite lady -PRON- volunteer meeting join -PRON- youth collision excite ij wq cs' => ['0' '0' '0' ... '1' '1' '0']
# '   forgiven angelina jolie sef' => ['0' '0' '0' ... '1' '1' '0']
# '   apologise sincerely inevitable deluge gbbo win hold grudge -PRON- decide unfollow baking cake' => ['0' '0' '0' ... '1' '1' '0']
# '   sonofbaldwin -PRON- nova bookslast -PRON- tie rider annihilation' => ['0' '0' '0' ... '1' '1' '0']
# '   house demolition cpnbbzkzg orcas island washington' => ['0' '0' '0' ... '1' '1' '0']
# '   modiministry madhya pradesh train derailment village youth yvmphd' => ['0' '0' '0' ... '1' '1' '0']
# ' gbbo physically gasp cake mudslide incident emotionally invest' => ['0' '0' '0' ... '1' '1' '0']
# ' national briefing west california spring oil spill estimate grow document release wednesday htxai nyt' => ['0' '0' '0' ... '1' '1' '0']
# ' brace -PRON- samaritans evening -PRON- inundate depressed arsenal fan hexpc otn' => ['0' '0' '0' ... '1' '1' '0']
# ' cancel fucking evacuate metlife skq oucm' => ['0' '0' '0' ... '1' '1' '0']
# '   emergency odai bucharest romania dog -PRON- hungry -PRON- pjigxpvpl' => ['0' '0' '0' ... '1' '1' '0']
# '   upload death smoochy awakening clip reason bicentennial pain ass' => ['0' '0' '0' ... '1' '1' '0']
# ' control -PRON- minute whirlwind drain' => ['0' '0' '0' ... '1' '1' '0']
# ' trillion crosse -PRON- field attack instant kill damage' => ['0' '0' '0' ... '1' '1' '0']
# ' trafford centre film fan angry odeon cinema evacuate false fire alarm gldwx da' => ['0' '0' '0' ... '1' '1' '0']
# ' selection september bridgeport charge invasion police burglar mlcd' => ['0' '0' '0' ... '1' '1' '0']
# ' eur free bet bwin sport market destroy free sikkg fphr jfyfzddlrn' => ['0' '0' '0' ... '1' '1' '0']
# '   bakeofffriends gbbo mudslide hat' => ['0' '0' '0' ... '1' '1' '0']
# ' devastation -PRON- smash -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' derail benchmark cool path -PRON- leak resque' => ['0' '0' '0' ... '1' '1' '0']
# ' typhoon soudelor dead aim taiwan ac wuy' => ['0' '0' '0' ... '1' '1' '0']
# ' burn flame' => ['0' '0' '0' ... '1' '1' '0']
# ' fear -PRON- risk' => ['0' '0' '0' ... '1' '1' '0']
# '   yahoocare -PRON- change -PRON- yahoo care -PRON- inundated complaint -PRON- respond -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- poem snowstorm -PRON- space -PRON- thx ur disney chann' => ['0' '0' '0' ... '1' '1' '0']
# '   deai suicide bomber kill saudi security site mosque sqydkslfzp' => ['0' '0' '0' ... '1' '1' '0']
# '   sirtophamhat scynic nafeezahme jeremydun -PRON- melt steel structural failure' => ['0' '0' '0' ... '1' '1' '0']
# '   igxrqpotm bin laden family plane crash avoid microlight landi kpbu hgt peritoengrafoscopia' => ['0' '0' '0' ... '1' '1' '0']
# ' police teenager arrest curfew violation evanston ride steal bicycle teenager cus chicago' => ['0' '0' '0' ... '1' '1' '0']
# ' robert gagnon catastrophe impose sex marriage christians respond hipklxphnp' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- free hailstorm maxi erws ieldg' => ['0' '0' '0' ... '1' '1' '0']
# ' demolish -PRON- personal imullbvue' => ['0' '0' '0' ... '1' '1' '0']
# ' rt naayf accident chandanee magu mma taxi ram -PRON- halfway conf' => ['0' '0' '0' ... '1' '1' '0']
# ' answer -PRON- friend blow wind -PRON- yell survive dust storm nwajli cr tkmotaeaco' => ['0' '0' '0' ... '1' '1' '0']
# '   toocodtodd wyattb challenge tornado tag tlc match winner' => ['0' '0' '0' ... '1' '1' '0']
# ' survive hiroshima nagasaki pnssia lsvsyspdxx' => ['0' '0' '0' ... '1' '1' '0']
# '   shekhargupta mihirssharma tv channel realise level -PRON- sink trp ad -PRON- mockery' => ['0' '0' '0' ... '1' '1' '0']
# '   tix calgary flame col avalanche preseason scotiabank saddledome qa mpxm' => ['0' '0' '0' ... '1' '1' '0']
# ' traffic freeze cold blaze hot heat -PRON- traffic ddiqig' => ['0' '0' '0' ... '1' '1' '0']
# ' warning central hills hail mph wind affect sturgis kotaweather epiyenqyl' => ['0' '0' '0' ... '1' '1' '0']
# ' rt truediagnosis death physician error dutyzqr avoid -PRON- oznsxxvx' => ['0' '0' '0' ... '1' '1' '0']
# ' apollo brown detonate xigcen' => ['0' '0' '0' ... '1' '1' '0']
# ' kontrolle medium -PRON- putin bad ww peace bad bs leave russia dice obliteration demonization' => ['0' '0' '0' ... '1' '1' '0']
# ' cabin fever flame yxnagsqvbm' => ['0' '0' '0' ... '1' '1' '0']
# ' dead demi moore swimming pool octnpyueei' => ['0' '0' '0' ... '1' '1' '0']
# ' desolation smaug spanish hell drug' => ['0' '0' '0' ... '1' '1' '0']
# ' tsutomi yamaguchi survive atomic bomb blast hiroshima nagasaki otd daalpenzp' => ['0' '0' '0' ... '1' '1' '0']
# '   terrorist shoot -PRON- vsoxkbt nq' => ['0' '0' '0' ... '1' '1' '0']
# '   dratomic -PRON- -PRON- trophy outbreak -PRON- photoshop -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' california oil spill xwxbyhtuzc wzedxefblg' => ['0' '0' '0' ... '1' '1' '0']
# '   motordom lobby change -PRON- language traffic fatality -PRON- future visionzero cavb pgepv' => ['0' '0' '0' ... '1' '1' '0']
# ' aftershock terrifying roller coaster disclaimer' => ['0' '0' '0' ... '1' '1' '0']
# '   panic idk -PRON- alarmingly calm' => ['0' '0' '0' ... '1' '1' '0']
# ' severe thunderstorm picture south uzwlgjqzns' => ['0' '0' '0' ... '1' '1' '0']
# ' hmm researcher fedex transport select agent viibxgjav usatoday' => ['0' '0' '0' ... '1' '1' '0']
# '   titortau loretta lynch fuckin larious realtime -PRON- train wreck checking ombudsmanship' => ['0' '0' '0' ... '1' '1' '0']
# '   update enugu government demolish illegal structure centre xcgzc gys daily' => ['0' '0' '0' ... '1' '1' '0']
# ' destruction tux ypwzur' => ['0' '0' '0' ... '1' '1' '0']
# '   siren join foot vvorm' => ['0' '0' '0' ... '1' '1' '0']
# ' explore moment explosion china mi ville otrwz sp xvlkfcvfx' => ['0' '0' '0' ... '1' '1' '0']
# ' god obliteration ancient canaanite hz lkffc worldnetdaily homosexuality downfall society' => ['0' '0' '0' ... '1' '1' '0']
# '   tammy elijahmallari bleed wild apartment -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- pretty wreck hahaha shoutout -PRON- family' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- tornado pass -PRON- -PRON- ocd -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   hot specially modify land stadium rescue hostage iran zlco ue oq prebreak' => ['0' '0' '0' ... '1' '1' '0']
# ' outbid rt lbpx bucnv catlow twister swivel dc fuel usa favorite shar' => ['0' '0' '0' ... '1' '1' '0']
# ' forget -PRON- wound female veteran rz fbr xw' => ['0' '0' '0' ... '1' '1' '0']
# '   stankyboy photo bomb' => ['0' '0' '0' ... '1' '1' '0']
# ' learn legacy catastrophic eruption yorker yqpbe' => ['0' '0' '0' ... '1' '1' '0']
# ' dust storm route alice spring uluru ilt fxu' => ['0' '0' '0' ... '1' '1' '0']
# ' build muscle feast famine feed diet plan base lose weight -PRON- lue waegpi' => ['0' '0' '0' ... '1' '1' '0']
# '   missdaoh -PRON- scream baby -PRON- love' => ['0' '0' '0' ... '1' '1' '0']
# ' pikin crash' => ['0' '0' '0' ... '1' '1' '0']
# ' israel continue -PRON- demolition palestinian gop potu irandeal isis nmgp imeii' => ['0' '0' '0' ... '1' '1' '0']
# '   squibby eyewitness ha' => ['0' '0' '0' ... '1' '1' '0']
# ' progress -PRON- middle age -PRON- burn -PRON- -PRON- content burn -PRON- sigmund freud' => ['0' '0' '0' ... '1' '1' '0']
# '   national park services tonto national forest annihilation salt river wild horse lojoorouk change' => ['0' '0' '0' ... '1' '1' '0']
# ' fedex transport bioterror pathogen wake anthrax lab mishap lhpgxc' => ['0' '0' '0' ... '1' '1' '0']
# '   sweet -PRON- fuck -PRON- existence obliterate' => ['0' '0' '0' ... '1' '1' '0']
# ' damn mlk center sink' => ['0' '0' '0' ... '1' '1' '0']
# ' south sac florin franklin blvd trfc collision enrt es lyway' => ['0' '0' '0' ... '1' '1' '0']
# ' gold gap obliterate player smash -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   dayton -PRON- -PRON- hit cyber attack lhkjz ivo' => ['0' '0' '0' ... '1' '1' '0']
# '   mrmikeeaton muazimus prime hill hill mountain volcano hell mountain hill hil' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- seclusion class evacuate child leave class force compliance morevoice' => ['0' '0' '0' ... '1' '1' '0']
# ' eh cover -PRON- bloody thigh -PRON- bloody cleav eh expose -PRON- cleavage kv ppxfg' => ['0' '0' '0' ... '1' '1' '0']
# '   financialtime ethiopian regime continue receive foreign famine strike eastern ethiopia fggzqn' => ['0' '0' '0' ... '1' '1' '0']
# ' people -PRON- interrupt -PRON- george bernard shaw' => ['0' '0' '0' ... '1' '1' '0']
# '   tsunami esh esh' => ['0' '0' '0' ... '1' '1' '0']
# '   sergiopiaggio level injury define -PRON- define -PRON- cool' => ['0' '0' '0' ... '1' '1' '0']
# ' swear secret -PRON- uncover god slumber blight' => ['0' '0' '0' ... '1' '1' '0']
# ' riot police intervene southampton vitesse arnhem supporter clash fan clash buildup skvnmtzgeg' => ['0' '0' '0' ... '1' '1' '0']
# ' burn story arsonist qxh cwd' => ['0' '0' '0' ... '1' '1' '0']
# ' dude bro massacre wqlobooy patrick bromleythe title sa thpbdpdj' => ['0' '0' '0' ... '1' '1' '0']
# ' fedex transport bioterror germ wake anthrax lab mishap sesqwm usatoday' => ['0' '0' '0' ... '1' '1' '0']
# '   spinningbot -PRON- stand user -PRON- detonate -PRON- -PRON- killer queen' => ['0' '0' '0' ... '1' '1' '0']
# '   tyt xrrk fear kill pakistani air ambulance helicopter crash nazoi' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- rescue -PRON- -PRON- pretend -PRON- giorgio hiatt' => ['0' '0' '0' ... '1' '1' '0']
# '   resident destroy washington wildfire burn uci stqug' => ['0' '0' '0' ... '1' '1' '0']
# '   rise follower graph follower -PRON- stat ulxf dq ns' => ['0' '0' '0' ... '1' '1' '0']
# ' turkish troop kill kurdish militant suicide attack cibxls' => ['0' '0' '0' ... '1' '1' '0']
# ' grenade impossible destroy hoe career' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- baaaack petersen bowhunte battle bow -PRON- cast -PRON- vote -PRON- fj gdvg' => ['0' '0' '0' ... '1' '1' '0']
# ' owner chicago gay admit arson scheme zpxe fmyng lgbt' => ['0' '0' '0' ... '1' '1' '0']
# ' tattoo woman base serial killer arkansas natural disaster nola' => ['0' '0' '0' ... '1' '1' '0']
# '   executive prosecute fukushima nuclear disaster zsdvweglf' => ['0' '0' '0' ... '1' '1' '0']
# ' reality training train fall elevated track windstorm jiomnrcygt paramedic ems' => ['0' '0' '0' ... '1' '1' '0']
# ' wreckage conclusively confirm mh malaysia investigator family kukmal' => ['0' '0' '0' ... '1' '1' '0']
# ' rocky fire northern california swell acre evacuate gw portland phoenix miami atlanta casper' => ['0' '0' '0' ... '1' '1' '0']
# ' morgan silver dollar gem bu dmpl cameo rev blaze grade kbqwior wrjr fks' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- annual football medium -PRON- cyclone hoop recruit nugget' => ['0' '0' '0' ... '1' '1' '0']
# ' police officer wound suspect dead exchange shot richmond police officer wound suspect kill eaoka' => ['0' '0' '0' ... '1' '1' '0']
# ' magic city mayhem kissimmee adventure fpyru golh' => ['0' '0' '0' ... '1' '1' '0']
# ' photo deadgirltalke unfortunemelody jaylenejoybeligan tarynel dredougie santanico pandemonium pvkgo jni' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- panic ogtomd zvre ffnyd' => ['0' '0' '0' ... '1' '1' '0']
# ' wsjthinktank gopdebate colleenmnelson explain bad debate derail campaign xyxtuaczvb' => ['0' '0' '0' ... '1' '1' '0']
# ' trial charge arson burglary wftcrlz' => ['0' '0' '0' ... '1' '1' '0']
# ' people panic cable tv bbjls fsad' => ['0' '0' '0' ... '1' '1' '0']
# '   ibaraki prefecture offing depth maximum seismic intensity earthquake' => ['0' '0' '0' ... '1' '1' '0']
# '   mariankeye rubber mudslide laugh' => ['0' '0' '0' ... '1' '1' '0']
# ' pharma overload loud emergency siren fucking' => ['0' '0' '0' ... '1' '1' '0']
# ' desolate valley transform thriving hub business' => ['0' '0' '0' ... '1' '1' '0']
# '   samaritans shoot horror hijacking yuualoqw chat twimbos zimpapersviews' => ['0' '0' '0' ... '1' '1' '0']
# '   executive prosecute fukushima nuclear disaster jssmmlnaq' => ['0' '0' '0' ... '1' '1' '0']
# ' crackdown destruction restrict multiplayer crackdown impress earlier demonstratio gwesgeszxv' => ['0' '0' '0' ... '1' '1' '0']
# ' china demolish fucking stone age' => ['0' '0' '0' ... '1' '1' '0']
# ' west valley trfc collision unkn inj js ehp wq' => ['0' '0' '0' ... '1' '1' '0']
# '   person ny legionnaire disease outbreak fjdm qhyai sebee' => ['0' '0' '0' ... '1' '1' '0']
# ' wave flood shore -PRON- -PRON- tdaktglu' => ['0' '0' '0' ... '1' '1' '0']
# ' deadpool -PRON- favourite marvel character -PRON- wear red suit bad -PRON- bleed' => ['0' '0' '0' ... '1' '1' '0']
# ' photo boyhaus heaven jake warm morning montana madison river evening fid' => ['0' '0' '0' ... '1' '1' '0']
# ' mac vuln oxxrnab' => ['0' '0' '0' ... '1' '1' '0']
# ' literally sink -PRON- backty' => ['0' '0' '0' ... '1' '1' '0']
# '   bangalore reddit update content policy promise quarantine extremely offensive community fgeu startup' => ['0' '0' '0' ... '1' '1' '0']
# ' butt trauma extraordinaire' => ['0' '0' '0' ... '1' '1' '0']
# '   msnbc fucking idiot -PRON- gun hatchet injury glad police terminate -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   zaynmalik overwork -PRON- -PRON- album fire overwork stress love -PRON- care' => ['0' '0' '0' ... '1' '1' '0']
# '   love fruit' => ['0' '0' '0' ... '1' '1' '0']
# ' punjab government flood relief platform vulrclw bd realtime inundation damage rescue effort travel alert' => ['0' '0' '0' ... '1' '1' '0']
# ' police gunman dead nashville theater suspect carry gun hatchet carmi kqvn utpmm' => ['0' '0' '0' ... '1' '1' '0']
# '   bug crash euro kgkz tk' => ['0' '0' '0' ... '1' '1' '0']
# '   camilacabello internally externally scream' => ['0' '0' '0' ... '1' '1' '0']
# '   friggin wreck destiel suck vine description mkx ux ozt' => ['0' '0' '0' ... '1' '1' '0']
# '   reason -PRON- love woman military lulgzimbestpict iapvtqxlht wamkre ckd' => ['0' '0' '0' ... '1' '1' '0']
# '   fatality mileena -PRON- sad' => ['0' '0' '0' ... '1' '1' '0']
# '   action ferguson upheaval tbqsqtmqv' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- mlg food collide ijustine salmon alaskaseafood askforalaska snyghaivs' => ['0' '0' '0' ... '1' '1' '0']
# ' providence health emergency supervisor emergency kodiak ak aqcsusqbdy healthcare' => ['0' '0' '0' ... '1' '1' '0']
# '   fedex transport bioterror germ wake anthrax lab mishap sicmyrmh' => ['0' '0' '0' ... '1' '1' '0']
# ' dq cotton candy blizzard' => ['0' '0' '0' ... '1' '1' '0']
# ' cancel -PRON- cat doctor appointment -PRON- decide curfew' => ['0' '0' '0' ... '1' '1' '0']
# ' deputies shoot brighton ablaze gwnrhmso' => ['0' '0' '0' ... '1' '1' '0']
# ' nigeria rainstorm destroy house yobe daily trust damaturu bbqnk qus' => ['0' '0' '0' ... '1' '1' '0']
# ' suppose fun fun accidentally burn arm lighter' => ['0' '0' '0' ... '1' '1' '0']
# ' freyas blow' => ['0' '0' '0' ... '1' '1' '0']
# '   puncture wind foreign body finger damage nail initial encounter icd' => ['0' '0' '0' ... '1' '1' '0']
# ' turkish troop kill kurdish militant suicide attack wd vci' => ['0' '0' '0' ... '1' '1' '0']
# '   caixxum sos damn heart attack' => ['0' '0' '0' ... '1' '1' '0']
# '   nytime upheaval create west iraq syria libya' => ['0' '0' '0' ... '1' '1' '0']
# '   atomic bomb japan struggle war anniversary devastation wrought bs xaqhsim' => ['0' '0' '0' ... '1' '1' '0']
# '   california spring oil spill estimate grow press nyt cx qb' => ['0' '0' '0' ... '1' '1' '0']
# '   auntiedote rioslade locke wiggin akarb obliteration govt -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   magazine satan daughter shadow warrior ft woman aka transgend mode ps nyc fold extra extra center bioterrorism' => ['0' '0' '0' ... '1' '1' '0']
# ' plane debris mh kxy fr vm' => ['0' '0' '0' ... '1' '1' '0']
# ' fall rock scrape -PRON- butt drown' => ['0' '0' '0' ... '1' '1' '0']
# '   fear migrant med rescuer search survivor boat carry ds xai' => ['0' '0' '0' ... '1' '1' '0']
# ' sf asian woman shelter crisis emergency shelter support speak asian woman child' => ['0' '0' '0' ... '1' '1' '0']
# ' suicide superpower america survive patrick buchana emtwirknyq oazve' => ['0' '0' '0' ... '1' '1' '0']
# '   fhi qbpwfh fredolsencruise faroeisland -PRON- itinerary mass murder dolphin whale' => ['0' '0' '0' ... '1' '1' '0']
# ' offer gl vc deluxe toilet safety support health bathroom support elderly injure vihdoksccc' => ['0' '0' '0' ... '1' '1' '0']
# '   remember mcdonalds -PRON- military mess' => ['0' '0' '0' ... '1' '1' '0']
# '   emiiliexirwin totally agree -PRON- birth control -PRON- derail -PRON- plan blame fan' => ['0' '0' '0' ... '1' '1' '0']
# '   honeybunzgem primalkitchen -PRON- pull stage apocalypse' => ['0' '0' '0' ... '1' '1' '0']
# ' whirlwind nostalgia' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- awful artist -PRON- ruin' => ['0' '0' '0' ... '1' '1' '0']
# ' annihilation transformation pyehwodwun alien attack exterminate human pb nskz' => ['0' '0' '0' ... '1' '1' '0']
# ' dan hughes stretcher danielle robinson collide ou wbball hope -PRON- -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' noel' => ['0' '0' '0' ... '1' '1' '0']
# ' juneau empire responder national uyt ojyk' => ['0' '0' '0' ... '1' '1' '0']
# '   zak bagan sabrina -PRON- dad rescue -PRON- dude -PRON- cage -PRON- -PRON- phqcuw' => ['0' '0' '0' ... '1' '1' '0']
# '   sigalert north southbound closed btwn fwy irvine blvd truck fire chp detour traffic' => ['0' '0' '0' ... '1' '1' '0']
# '   ruin -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   kabarmesir badr crime rabaa massacre revolution observe rememberrabaa' => ['0' '0' '0' ... '1' '1' '0']
# ' national rock severe thunderstorm warning van buren county kjsvw gbv' => ['0' '0' '0' ... '1' '1' '0']
# '   creationsbykole cork city ireland -PRON- degree heat wave -PRON- haha' => ['0' '0' '0' ... '1' '1' '0']
# '   chapoutier croze hermitage purple violet slate crush gravel white pepper yum france wine dc skvwn hz' => ['0' '0' '0' ... '1' '1' '0']
# ' breathe -PRON- windstorm haha cool' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- quora answer -PRON- answer collapse ikfmektpcx' => ['0' '0' '0' ... '1' '1' '0']
# '   hot funtenna hijacking datum wave black hat aqs loxu prebreak' => ['0' '0' '0' ... '1' '1' '0']
# ' imagine wall lava lamp' => ['0' '0' '0' ... '1' '1' '0']
# '   modiministry rly tragedy mp recount horror -PRON- oe' => ['0' '0' '0' ... '1' '1' '0']
# ' music action shit burn building police chase weak ben winston shit' => ['0' '0' '0' ... '1' '1' '0']
# '   tropical cyclone soudelor hpa maximum wind speed maximum wind gust speed nbd ot iew' => ['0' '0' '0' ... '1' '1' '0']
# ' mtr hazardous outlook hwo tglk uus' => ['0' '0' '0' ... '1' '1' '0']
# '   piece write avalanche design blog -PRON- greatly -PRON- -PRON- rfvjh ef' => ['0' '0' '0' ... '1' '1' '0']
# ' update survive canoe fast feed history' => ['0' '0' '0' ... '1' '1' '0']
# ' woman gps app rescuer injure biker marin county sfgate iz bhfaa' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- offer preventative cabling bracing structural failure -PRON- tree ct' => ['0' '0' '0' ... '1' '1' '0']
# ' drown squirrel absolutely incredible yzzxxknism zzsee hipm' => ['0' '0' '0' ... '1' '1' '0']
# '   alexbelloli -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' forest spend -PRON- annual budget fight fire climatechange zfzy mi' => ['0' '0' '0' ... '1' '1' '0']
# '   guiltygearxxacp blaze blue twitt lol draw sk flzz' => ['0' '0' '0' ... '1' '1' '0']
# '   sinkhole grow brooklyn meter crater swallows street gkprvzq lk' => ['0' '0' '0' ... '1' '1' '0']
# ' incident injury loop exit md georgia ave silver spring' => ['0' '0' '0' ... '1' '1' '0']
# '   emotional wreck' => ['0' '0' '0' ... '1' '1' '0']
# ' crew -PRON- peace love rescue' => ['0' '0' '0' ... '1' '1' '0']
# ' intact mh lift odd plane glide crash sea mjtn qbgos yahoofinance hope answer' => ['0' '0' '0' ... '1' '1' '0']
# '   babysweet mad -PRON- -PRON- blaze' => ['0' '0' '0' ... '1' '1' '0']
# ' hobbit desolation smaug sheeran fire hd oxrwrjzmnu' => ['0' '0' '0' ... '1' '1' '0']
# ' afghan soldier kill -PRON- america ranking fatality vietnam sihqpluidw' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- ipod explode -PRON- charging shit spark akxbskdn' => ['0' '0' '0' ... '1' '1' '0']
# ' fifa pre season tournament career mode bloody hell evacuate building whocare' => ['0' '0' '0' ... '1' '1' '0']
# ' meat love feminist riot grill arrive udqa kfqu' => ['0' '0' '0' ... '1' '1' '0']
# ' music action shit burn building police chase weak ben winston shit' => ['0' '0' '0' ... '1' '1' '0']
# ' halsey troye collab bomb' => ['0' '0' '0' ... '1' '1' '0']
# ' cartoon bear -PRON- -PRON- qave knowlddge forest fire toilet' => ['0' '0' '0' ... '1' '1' '0']
# ' demolition house waterway achimota mile liveonline story io kuug uq' => ['0' '0' '0' ... '1' '1' '0']
# '   gamefeed warcraft inspire mode hit hero storm gx kz tc videogame' => ['0' '0' '0' ... '1' '1' '0']
# '   fire' => ['0' '0' '0' ... '1' '1' '0']
# ' crush' => ['0' '0' '0' ... '1' '1' '0']
# ' medieval airplane hijacker cast star deviating dyxtmrydu' => ['0' '0' '0' ... '1' '1' '0']
# ' nations plantation forest cic rainforestresq' => ['0' '0' '0' ... '1' '1' '0']
# '   ledofficial -PRON- imagine -PRON- inundate request sample -PRON- love sweet' => ['0' '0' '0' ... '1' '1' '0']
# ' accuse fatal hit judge rtf dt khqa' => ['0' '0' '0' ... '1' '1' '0']
# '   xdescry wrong -PRON- trusty -PRON- spontaneously collapse -PRON- trusty' => ['0' '0' '0' ... '1' '1' '0']
# ' bigrigradio accident awareness' => ['0' '0' '0' ... '1' '1' '0']
# '   demoness voice angel siren beckon -PRON- void nps xpbkaq' => ['0' '0' '0' ... '1' '1' '0']
# ' campaign ferrell zach galifianaki commit comic mayhem hilarious political farce tq qgtzq' => ['0' '0' '0' ... '1' '1' '0']
# ' akilah cop pull avoid vn fnmy li' => ['0' '0' '0' ... '1' '1' '0']
# '   mzgraciebaby record -PRON- jumpin window officialrealrap body bagging luck lol file' => ['0' '0' '0' ... '1' '1' '0']
# ' revise death america scenario casualty iranian activity suspect drlkebeypi' => ['0' '0' '0' ... '1' '1' '0']
# ' suicide bomber kill saudi security site mosque axk xno yz mercados' => ['0' '0' '0' ... '1' '1' '0']
# ' dead train derail river india zkkn mse fzhjf bxld' => ['0' '0' '0' ... '1' '1' '0']
# ' wreckage conclusively confirm mh malaysia' => ['0' '0' '0' ... '1' '1' '0']
# ' chemical brother armory sf emergency bay edm announcement chem ln trhw' => ['0' '0' '0' ... '1' '1' '0']
# '   kca votejkt -PRON- duckvillelol burn flip table screw hit building grabs nwqdje' => ['0' '0' '0' ... '1' '1' '0']
# '   rhee deliciousvomit -PRON- lucky -PRON- -PRON- family body bag' => ['0' '0' '0' ... '1' '1' '0']
# '   likeavillasboas rich chandler injury prone suffer injury' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- uplift spirit -PRON- drown -PRON- anchor' => ['0' '0' '0' ... '1' '1' '0']
# ' cascada evacuate dancefloor official ohcx' => ['0' '0' '0' ... '1' '1' '0']
# ' legionnaire disease deadly outbreak bad outbreak legio ubg wfyge losangele' => ['0' '0' '0' ... '1' '1' '0']
# ' warfighte robot reduce civilian casualty dvu ridz' => ['0' '0' '0' ... '1' '1' '0']
# '   atomic bomb japan struggle war anniversary devastation wrought ag sgo' => ['0' '0' '0' ... '1' '1' '0']
# '   weapon music rock -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- lilithsaintcrow release blood ancient evil trap eswnsetftf' => ['0' '0' '0' ... '1' '1' '0']
# ' emotional wreck emmerdale summerfate mikeparractor misscharleywebb' => ['0' '0' '0' ... '1' '1' '0']
# ' mind blow glassanimal slither viscous gold cover erykah badu zb gm' => ['0' '0' '0' ... '1' '1' '0']
# '   handbag fashion hpd snm oy vintage coach purse camera bag cross body bid gsmddmu pu' => ['0' '0' '0' ... '1' '1' '0']
# ' access extensive threat box add -PRON- internal intelligence bhusa' => ['0' '0' '0' ... '1' '1' '0']
# '   lightning wolf -PRON- activity directory' => ['0' '0' '0' ... '1' '1' '0']
# ' japan fuso class battleship yamashiro naval cover photo cachet sink wwii aq zlim fvr jdq' => ['0' '0' '0' ... '1' '1' '0']
# '   capoeira class stretcher bearer' => ['0' '0' '0' ... '1' '1' '0']
# ' rt huffpostcomedy -PRON- build wall burn attendee xwvw sft hukhwmal' => ['0' '0' '0' ... '1' '1' '0']
# '   shipsxanchor idek people -PRON- terrorist' => ['0' '0' '0' ... '1' '1' '0']
# ' wreck wreck wreck wreck wreck wreck wreck wreck wreck wreck wreck wreck wreck' => ['0' '0' '0' ... '1' '1' '0']
# '   welovela nhlducks avalanche defense -PRON- match st louis blues rvcomh sportsroadhouse' => ['0' '0' '0' ... '1' '1' '0']
# ' shadow box apocalypse' => ['0' '0' '0' ... '1' '1' '0']
# ' china stock market crash gem rubble bqblwiw roimentor yycwalk' => ['0' '0' '0' ... '1' '1' '0']
# '   mayoroflondon pls reduce cyclist death compulsory highway code test vehicle road notrocketscience' => ['0' '0' '0' ... '1' '1' '0']
# ' catastrophic hiroshima nagasaki atomic bombing tgcr vofj' => ['0' '0' '0' ... '1' '1' '0']
# '   lightumupbeast pre -PRON- dick thunder' => ['0' '0' '0' ... '1' '1' '0']
# '   drdrewhln meltdown areva -PRON- control kid' => ['0' '0' '0' ... '1' '1' '0']
# ' survivor remorse' => ['0' '0' '0' ... '1' '1' '0']
# '   pllolz graze stretcher invalid witter towel' => ['0' '0' '0' ... '1' '1' '0']
# ' blast benediction sanelesstheory metal devastation radio sigeeq cz' => ['0' '0' '0' ... '1' '1' '0']
# ' future therapy technology sport sexuality bioterrorism diagnosis digitalhealth hcsm' => ['0' '0' '0' ... '1' '1' '0']
# ' accident ashville sb sr traffic hylmo wgfi' => ['0' '0' '0' ... '1' '1' '0']
# '   ir icemoon aftershock thyzomvwu djicemoon dubstep trapmusic dnb edm dance ices joo xk' => ['0' '0' '0' ... '1' '1' '0']
# '   ckosova whirlwind bomb' => ['0' '0' '0' ... '1' '1' '0']
# '   whao nigerian refugee repatriate cameroon huhwpmrywz' => ['0' '0' '0' ... '1' '1' '0']
# '   pbban temporary russaky armageddon kill flag fast xp reason' => ['0' '0' '0' ... '1' '1' '0']
# '   amirkingkhan -PRON- annihilate -PRON- floydmayweather' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- engulf image quiz dspdkruk nep azwkna' => ['0' '0' '0' ... '1' '1' '0']
# ' parker ridge sheet parker ridge wildfire email pa ezeisasm idfire' => ['0' '0' '0' ... '1' '1' '0']
# ' sit fire' => ['0' '0' '0' ... '1' '1' '0']
# '   doctorfluxx stefanejone spinnellii themermacorn burn building rob riot embarrass ruin nation' => ['0' '0' '0' ... '1' '1' '0']
# '   progress boise forest fire mgmghgt wtpo elrzd' => ['0' '0' '0' ... '1' '1' '0']
# ' japan thursday mark anniversary atomic bombing hiroshima senior official washington schedule' => ['0' '0' '0' ... '1' '1' '0']
# '   earthquake worry emmy rossum fine' => ['0' '0' '0' ... '1' '1' '0']
# ' destroy -PRON- childhood' => ['0' '0' '0' ... '1' '1' '0']
# ' mafireems rt wmur building involve fire street manchester wmur qufwxrjiql kcarosawmur' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- pick body water rescuer search migrant mediterranean boat carryi' => ['0' '0' '0' ... '1' '1' '0']
# ' fco minister tobias ellwood condemn attack mosque saudi arabia death ozz' => ['0' '0' '0' ... '1' '1' '0']
# ' bulgarian tittie twister noemotion produce edk pathfinder hd odqryjncf' => ['0' '0' '0' ... '1' '1' '0']
# ' build -PRON- lead -PRON- army victory youtu friend code lzktjnox zz cewew' => ['0' '0' '0' ... '1' '1' '0']
# ' bay district coach learn cpr medical panama city athlete collapse field coach kfkaosh kh' => ['0' '0' '0' ... '1' '1' '0']
# ' infected bloody ear piercing fun' => ['0' '0' '0' ... '1' '1' '0']
# ' mmmmmm burn burn building build oooooohhhh oooh ooh' => ['0' '0' '0' ... '1' '1' '0']
# ' poor liv -PRON- wreck oliviaapalmerr thatswhatfriendsarefor' => ['0' '0' '0' ... '1' '1' '0']
# ' rt geek apocalypse gmt hesse dark souls tngpshnl imzlnzltf etcpb' => ['0' '0' '0' ... '1' '1' '0']
# '   obliterate' => ['0' '0' '0' ... '1' '1' '0']
# ' buy bag leave' => ['0' '0' '0' ... '1' '1' '0']
# '   plan panic bc' => ['0' '0' '0' ... '1' '1' '0']
# ' womens tote faux leather handbag shoulder cross body handle bag rise gyzpisbi msdntkwyaf' => ['0' '0' '0' ... '1' '1' '0']
# '   hot funtenna hijacking datum wave black hat qj pvgavn prebreak' => ['0' '0' '0' ... '1' '1' '0']
# ' obsolete devastation broad ball root -PRON- bat hand ashe engvaus tjawwtj' => ['0' '0' '0' ... '1' '1' '0']
# ' legionnairesdisease outbreak pneumonia americanlegion convention philly -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   kill simultaneous rail crash acute flood derail train india mumbai kbwpcmmbm' => ['0' '0' '0' ... '1' '1' '0']
# ' mad river complex fire burn acre mad river complex fire trinity county lfnippnoto' => ['0' '0' '0' ... '1' '1' '0']
# '   exotic wreck train accident xeuj ps' => ['0' '0' '0' ... '1' '1' '0']
# ' reddit quarantine offensive content wosypvqufi xw sds tjp' => ['0' '0' '0' ... '1' '1' '0']
# ' coastal german shepherd rescue oc share link ecstatic rescue racco dzvgwx animalrescue' => ['0' '0' '0' ... '1' '1' '0']
# ' snowstorm plan rome st mary annual occasion artificial snow remember snow ad spot' => ['0' '0' '0' ... '1' '1' '0']
# '   piece israeli incitement jewish terrorism beinart ot oooedts' => ['0' '0' '0' ... '1' '1' '0']
# '   hope -PRON- fall cliff' => ['0' '0' '0' ... '1' '1' '0']
# '   funnynews business moment cliff collapse huge chunk rock fall road china lci pljx' => ['0' '0' '0' ... '1' '1' '0']
# ' fight bioterrorism sir' => ['0' '0' '0' ... '1' '1' '0']
# '   tweetlikeitsseptember building fire' => ['0' '0' '0' ... '1' '1' '0']
# '   josh lado drive joshua typos hazardous' => ['0' '0' '0' ... '1' '1' '0']
# ' equally incapable nothingness -PRON- emerge infinity -PRON- engulf blaise pascal' => ['0' '0' '0' ... '1' '1' '0']
# ' potential storm surge flooding map national hurricane center jzwrwlvlsj ot bjjhh' => ['0' '0' '0' ... '1' '1' '0']
# ' llf record hurricane drought hit hurricane irhwg' => ['0' '0' '0' ... '1' '1' '0']
# '   swayoung recognise -PRON- smile emergency perform art follower simon' => ['0' '0' '0' ... '1' '1' '0']
# '   pbban temporary fighterdena armageddon kill flag fast xp reason' => ['0' '0' '0' ... '1' '1' '0']
# ' learn evacuate -PRON- event wildfire bgerljamte nv ut spuhuvgasy' => ['0' '0' '0' ... '1' '1' '0']
# '   sarniamakchris hromadske kasiadear silly country destroy security' => ['0' '0' '0' ... '1' '1' '0']
# '   pair lead drive flood light road atv utv ebay xdlec ddvh fy' => ['0' '0' '0' ... '1' '1' '0']
# '   stury passenger board train derail morning' => ['0' '0' '0' ... '1' '1' '0']
# ' pack pack pack fleek stretcher fire' => ['0' '0' '0' ... '1' '1' '0']
# ' bad lightning thunder crack' => ['0' '0' '0' ... '1' '1' '0']
# ' ton telemarketing -PRON- cell deluge' => ['0' '0' '0' ... '1' '1' '0']
# '   tareksocal celebrity treat ppl -PRON- harm -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' hurricane sick' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- devastation -PRON- shocking firefighter continue battle flame california benstracy' => ['0' '0' '0' ... '1' '1' '0']
# ' europe nature -PRON- -PRON- tornados hurricane wild fire earthquake flash flood mega snow drought' => ['0' '0' '0' ... '1' '1' '0']
# '   atomic bomb japan struggle war anniversary devastation ltvvpflsg' => ['0' '0' '0' ... '1' '1' '0']
# ' heat wave' => ['0' '0' '0' ... '1' '1' '0']
# ' cancer equate death blackpool kowe sign -PRON- dvqjvxpo beclearoncancer' => ['0' '0' '0' ... '1' '1' '0']
# '   antpip johnejefferson aware country -PRON- bomb flee conflict' => ['0' '0' '0' ... '1' '1' '0']
# ' family sue legionnaire family affect fatal outbreak legionnaire disea paje mxn' => ['0' '0' '0' ... '1' '1' '0']
# ' warning central hills hail mph wind affect sturgis kotaweather qo vwfelkp' => ['0' '0' '0' ... '1' '1' '0']
# '   anniversary marilyn monroe death ripriprip' => ['0' '0' '0' ... '1' '1' '0']
# '   jannet fall hit -PRON- concrete bleed shit' => ['0' '0' '0' ... '1' '1' '0']
# ' exploration seismic shift gabon somalia ltf jl keu zlq thctkw' => ['0' '0' '0' ... '1' '1' '0']
# ' israeli soldier wound west bank terrorist attack haaretz gsbnu wc' => ['0' '0' '0' ... '1' '1' '0']
# ' trouble buffett favorite sector dqpflmkr' => ['0' '0' '0' ... '1' '1' '0']
# ' spider bite fatality australia' => ['0' '0' '0' ... '1' '1' '0']
# '   graysondolan -PRON- drown -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   catastrophic flooding -PRON- yrbegzafx' => ['0' '0' '0' ... '1' '1' '0']
# ' marley brinx striptease spread -PRON- leg pussy pounding qew xd download' => ['0' '0' '0' ... '1' '1' '0']
# ' oops bounty hunter raid phoenix police chief armed bounty hunter surround dgelj ryt' => ['0' '0' '0' ... '1' '1' '0']
# ' hollywood movie trap miner release chile qkrltrd' => ['0' '0' '0' ... '1' '1' '0']
# '   thunderstorm' => ['0' '0' '0' ... '1' '1' '0']
# ' chance animal rescue kiildu gpo animalrescue wudlkq ncx' => ['0' '0' '0' ... '1' '1' '0']
# ' failure misfortunebut regret catastrophe' => ['0' '0' '0' ... '1' '1' '0']
# ' breakfast link derail train derail smithsonian morning suspend ser -PRON- qgqdnjq' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- tactical riot headquarters disney marvel' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- question interpretation sign apocalypse -PRON- -PRON- uwijn' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- -PRON- curfew -PRON- -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   bobbyofhomewood joxroundtable drop sport si derail' => ['0' '0' '0' ... '1' '1' '0']
# ' hit roadway property damage statesville' => ['0' '0' '0' ... '1' '1' '0']
# ' honestly modibo maiga steal fuck -PRON- -PRON- -PRON- danger fucktard coyi' => ['0' '0' '0' ... '1' '1' '0']
# ' movie theater attack thankful casualty -PRON- evil win' => ['0' '0' '0' ... '1' '1' '0']
# '   shayoly love -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' outdoor postere calgaryfringe mothernature hailstorm yycfringe killhard' => ['0' '0' '0' ... '1' '1' '0']
# '   brandonmulcahy fpine story tgxutuoyhl' => ['0' '0' '0' ... '1' '1' '0']
# ' jen -PRON- da bomb czqr ci xw' => ['0' '0' '0' ... '1' '1' '0']
# ' sioux city fire official bridge collapse lead cement truck roll siouxland matter siouxlan sztgmbkohg' => ['0' '0' '0' ... '1' '1' '0']
# ' rip mama thuggin war zone' => ['0' '0' '0' ... '1' '1' '0']
# ' bae soak -PRON- mudslide backroom thisiswhywecanthavenicething kgxnwziuxd' => ['0' '0' '0' ... '1' '1' '0']
# ' nbcnightlynews malaysian official debris reunion island mh billneelynbc foutpwgfwy' => ['0' '0' '0' ... '1' '1' '0']
# 'nan' => ['0' '0' '0' ... '1' '1' '0']
# ...
# ' aware battle support -PRON- fight mctjnzx' => ['0' '0' '0' ... '1' '1' '0']
# ' corii siren spoil -PRON- gizrucy wishlist hgedwxtdjn' => ['0' '0' '0' ... '1' '1' '0']
# '   filming nuclear reactor chernobyl sonyprousa lumixusa djiglobal profbriancox rt america gljhvead' => ['0' '0' '0' ... '1' '1' '0']
# ' mark fatality reoz -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# '   grade black horse famine mega score pdiit af dynamix zq kdox' => ['0' '0' '0' ... '1' '1' '0']
# ' cleared incident injury loop exit md georgia ave silver spring' => ['0' '0' '0' ... '1' '1' '0']
# ' level tita dom bowling injury tdeqwm zxn' => ['0' '0' '0' ... '1' '1' '0']
# '   charge manslaughter toddler charge manslaughter fatal sh' => ['0' '0' '0' ... '1' '1' '0']
# ' attention rchs football player coffin body bag locker grab tommorow' => ['0' '0' '0' ... '1' '1' '0']
# '   people receive wildfire evacuation california' => ['0' '0' '0' ... '1' '1' '0']
# '   meekmill rec league ball drake olympic level body bag -PRON- -PRON- career trollingtilmeekdiss' => ['0' '0' '0' ... '1' '1' '0']
# '   commercial -PRON- sister meltdown' => ['0' '0' '0' ... '1' '1' '0']
# '   stationcdrkelly support sys usagov hostage blk -PRON- clergyforce exist grossly disfigure bioterrorism' => ['0' '0' '0' ... '1' '1' '0']
# ' nike golf storm fit golf jacket black medium jvai vkmsy sportinggoods nr jjmpmos' => ['0' '0' '0' ... '1' '1' '0']
# '   nbcpolitic russia fire bombing marine barrack suicide bomber attack site' => ['0' '0' '0' ... '1' '1' '0']
# ' refugio oil spill costlier pszkvx' => ['0' '0' '0' ... '1' '1' '0']
# ' bsg hype -PRON- delay -PRON- utterly utterly blow' => ['0' '0' '0' ... '1' '1' '0']
# '   drive -PRON- parent lmao panic attack' => ['0' '0' '0' ... '1' '1' '0']
# ' navy sideline subs okamsczbwg' => ['0' '0' '0' ... '1' '1' '0']
# '   joedawg tor tor situation wind damage enhance wording key imo' => ['0' '0' '0' ... '1' '1' '0']
# ' hazard pay' => ['0' '0' '0' ... '1' '1' '0']
# '   johngreen storm silence robthier' => ['0' '0' '0' ... '1' '1' '0']
# ' magnetic electrostatic nuclear fusion reactor -PRON- opytbpg' => ['0' '0' '0' ... '1' '1' '0']
# ' nuclear deal disaster irandeal nonucleariran badirandeal jebbush barackobama phpjtqud' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- age mess wild -PRON- fun -PRON- wreck' => ['0' '0' '0' ... '1' '1' '0']
# ' fear kill pakistani air ambulance helicopter crash ywbbeet worldnews' => ['0' '0' '0' ... '1' '1' '0']
# ' barackobama rescind medal -PRON- soldier massacre wound knee sign rt driuac' => ['0' '0' '0' ... '1' '1' '0']
# ' christian attack muslims temple mount wave israeli flag pamela geller mxz yx' => ['0' '0' '0' ... '1' '1' '0']
# ' hellfire surround desire careful -PRON- desire control -PRON- afterlife' => ['0' '0' '0' ... '1' '1' '0']
# ' raw dust storm roll texas qllkofdyzx rgjjumnnah' => ['0' '0' '0' ... '1' '1' '0']
# '   hot funtenna hijacking datum wave black hat mis rjxuir prebreak' => ['0' '0' '0' ... '1' '1' '0']
# ' messi tattoos -PRON- donate blood ronaldo burn building dog' => ['0' '0' '0' ... '1' '1' '0']
# '   crushed pace nike sportwatch gps nikeplus vweq es' => ['0' '0' '0' ... '1' '1' '0']
# ' lady rockin death metal -PRON- sedan downtown smoking cigarette -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' patrick roy upper deck spx finite colorado avalanche mint uhfm tq qulgakebhb' => ['0' '0' '0' ... '1' '1' '0']
# ' kalmikya astrakhan volgagrad dagestan food leave locust fw zwxtp timeworld' => ['0' '0' '0' ... '1' '1' '0']
# ' shirley caesar windstorm koch slasq nowplaye listenlive' => ['0' '0' '0' ... '1' '1' '0']
# ' wmata train derail smithsonian' => ['0' '0' '0' ... '1' '1' '0']
# ' trynna smoke tj -PRON- hoe' => ['0' '0' '0' ... '1' '1' '0']
# ' wreckage conclusively confirm mh malaysia investigator family xb zwyhct' => ['0' '0' '0' ... '1' '1' '0']
# ' love twister thetwister maddie tae oktxduo' => ['0' '0' '0' ... '1' '1' '0']
# ' russian food crematoria provoke outrage crisis famine memories yahoo siirlnv' => ['0' '0' '0' ... '1' '1' '0']
# ' malaysia france plane debris mh exznmxbinj' => ['0' '0' '0' ... '1' '1' '0']
# ' fuck neil fall cliff' => ['0' '0' '0' ... '1' '1' '0']
# '   ayekoradio brasswork agency crush shaken qh axvhwh radio netlabel electronicmusic ccmusic' => ['0' '0' '0' ... '1' '1' '0']
# '   metepec mexico disaster oficial nitclub sica sica wtfjf jjzs' => ['0' '0' '0' ... '1' '1' '0']
# ' drought fuels bush fire jamaica ymf txfch ngent jamaicaobserver cnewslive jyiekeo -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' roger goodell fatal mistake tom brady innocent ucnckrnlow' => ['0' '0' '0' ... '1' '1' '0']
# ' houston nyc collide pageparkescorp chloeunguyen laurensicle charsteven tiara marei gemma bowe wowps vd' => ['0' '0' '0' ... '1' '1' '0']
# ' rory mcilroy test ankle injury chinadotcom sports udtgwfsc wsx lqn' => ['0' '0' '0' ... '1' '1' '0']
# '   mark argent finish catastrophe amazing' => ['0' '0' '0' ... '1' '1' '0']
# ' civilian casualty rise afghan war intensifie nnylxhinpx' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- mama scare thunder' => ['0' '0' '0' ... '1' '1' '0']
# '   particulate break solid combust fossil fuel voltaic active forest fire biological voc petroleum ch bacteria decomposition' => ['0' '0' '0' ... '1' '1' '0']
# '   morehouse -PRON- -PRON- govt lose ethical moral relevance usa population danger -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' people worried burning building black people lose -PRON- disgusting' => ['0' '0' '0' ... '1' '1' '0']
# ' rly tragedy mp recount horror coach -PRON- train plunge water calk nv vc' => ['0' '0' '0' ... '1' '1' '0']
# ' disaster avert police kill gunman hoax device cinema ng fzpvds' => ['0' '0' '0' ... '1' '1' '0']
# ' ur gf excuse bitch fight -PRON- hold hostage' => ['0' '0' '0' ... '1' '1' '0']
# ' writing cyxbrzxwq' => ['0' '0' '0' ... '1' '1' '0']
# '   pandemonium aba woman deliver baby gccapaak nqjzs wkun' => ['0' '0' '0' ... '1' '1' '0']
# ' psalms lord redeemeth soul -PRON- servant -PRON- trust -PRON- desolate' => ['0' '0' '0' ... '1' '1' '0']
# '   eazzy -PRON- govt -PRON- belief warrant death innocent jap' => ['0' '0' '0' ... '1' '1' '0']
# ' rt abbswinston zionist terrorist kidnap palestinians overnight terror palestinian village mkcbkcov' => ['0' '0' '0' ... '1' '1' '0']
# ' detonate feat grandeur apollo brown gfdhfmpcel' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- drown -PRON- insult devote pride fold action reprocussion birth retroactive' => ['0' '0' '0' ... '1' '1' '0']
# '   putin decree destruction ton import cheese russia ukraine border rt independent pnnktlxh' => ['0' '0' '0' ... '1' '1' '0']
# ' free aftershock tc' => ['0' '0' '0' ... '1' '1' '0']
# ' fight bioterrorism sir' => ['0' '0' '0' ... '1' '1' '0']
# ' dead space obliteration imminent xjb dcaahf' => ['0' '0' '0' ... '1' '1' '0']
# ' motorcyclist bicyclist injure denver collision broadway cn yxjq kierannicholson' => ['0' '0' '0' ... '1' '1' '0']
# '   joshsternberg -PRON- feed deluge -PRON- fantastic' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- tipster preview chelsea swansea pfsryjs pc chelsea hazard skdbot tgf' => ['0' '0' '0' ... '1' '1' '0']
# ' reddit quarantine offensive content ltmgdp jaf' => ['0' '0' '0' ... '1' '1' '0']
# '   bug patch os active exploit hijack mac sbgirvqvzb' => ['0' '0' '0' ... '1' '1' '0']
# ' hiroshima atomic bomb sanitised narrative hiroshima atomic bombing gkpanz vg' => ['0' '0' '0' ... '1' '1' '0']
# ' usgs eq anchorage alaska utc ojq kfg ub earthquake' => ['0' '0' '0' ... '1' '1' '0']
# '   sirensicebreaker fantasy diverse heroine -PRON- hpljur obo' => ['0' '0' '0' ... '1' '1' '0']
# '   scream -PRON- dad step' => ['0' '0' '0' ... '1' '1' '0']
# ' chicago fd box alarm ems plan st calumet train derailment cins tg' => ['0' '0' '0' ... '1' '1' '0']
# '   australia japan marks anniversary hiroshima atomic bombing ad cgee hhzql tznp' => ['0' '0' '0' ... '1' '1' '0']
# ' black eye space battle occur star involve fleet ship destroy' => ['0' '0' '0' ... '1' '1' '0']
# ' fel lord zakuun hellfire wod onv ux' => ['0' '0' '0' ... '1' '1' '0']
# ' wall invincible history blood dance floor zntg wndmj' => ['0' '0' '0' ... '1' '1' '0']
# ' memorial unveil travis county deputy kill sept flooding travis county sheriff greg hamilton join eo wxpz' => ['0' '0' '0' ... '1' '1' '0']
# ' ukraine argue weapon pelosi visit kiev jnn krnxvy loiwuyv' => ['0' '0' '0' ... '1' '1' '0']
# ' roof collapse bowl alley community remember kezi sahbhlxssh' => ['0' '0' '0' ... '1' '1' '0']
# '   vantage backup eastbound visibility dust storm miles east bridge' => ['0' '0' '0' ... '1' '1' '0']
# '   lunasagalle synapsenkotze exploded bean bastard' => ['0' '0' '0' ... '1' '1' '0']
# '   mayhem -PRON- leave' => ['0' '0' '0' ... '1' '1' '0']
# '   usnwsgov severe statement august edt nws severe thunderstorm warning huen rwrn' => ['0' '0' '0' ... '1' '1' '0']
# ' bluedio turbine hurricane bluetooth wireless stereo headphone headset blk fd lf sdmichb' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- -PRON- fire burn' => ['0' '0' '0' ... '1' '1' '0']
# '   dirk trossen snowstorm hailstorm' => ['0' '0' '0' ... '1' '1' '0']
# '   team usagi -PRON- blow solar airhead misstep' => ['0' '0' '0' ... '1' '1' '0']
# ' love weapon wound generation lt' => ['0' '0' '0' ... '1' '1' '0']
# ' wreckage confirm malaysia airlines flight mh yopeypjkb' => ['0' '0' '0' ... '1' '1' '0']
# '   recipe mudslide cake stew gbbo' => ['0' '0' '0' ... '1' '1' '0']
# '   thesewphist hold fuckface wineisdumb deluge spam -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' audio business owner share -PRON- utqe zfde' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- change chronicillness avoid -PRON- survive join mylifestory gt gt gt fyjwjdkm' => ['0' '0' '0' ... '1' '1' '0']
# ' alabamaquake seismic summary earthquake history zm vczqvwk dknlznom' => ['0' '0' '0' ... '1' '1' '0']
# ' demolish unrecognized arab village middle east medium center ik yi' => ['0' '0' '0' ... '1' '1' '0']
# '   ferguson change -PRON- vmmdebdx' => ['0' '0' '0' ... '1' '1' '0']
# '   blizzard draco -PRON- free art kamon' => ['0' '0' '0' ... '1' '1' '0']
# '   lightning ooc unwarranted sexual conversation' => ['0' '0' '0' ... '1' '1' '0']
# ' harshness -PRON- sarah race scream siren pace prontouo' => ['0' '0' '0' ... '1' '1' '0']
# ' ted cruz bash obama comparison gop iranians shout death america cufgvupkzi' => ['0' '0' '0' ... '1' '1' '0']
# ' leader zionism burn baby xysdn xz' => ['0' '0' '0' ... '1' '1' '0']
# ' fionagilbert delay inundate -PRON- -PRON- -PRON- asap' => ['0' '0' '0' ... '1' '1' '0']
# '   lt meltdown proportion commence manage calm -PRON- water hot steam cloud -PRON- vision' => ['0' '0' '0' ... '1' '1' '0']
# ' flatten cartoony papa zmcqrmois' => ['0' '0' '0' ... '1' '1' '0']
# '   fewmoretweet matter fan burn building steal -PRON- neighbor protest' => ['0' '0' '0' ... '1' '1' '0']
# '   cnni prisonplanet climate change cnn specialist warn wild fire flooding sun szwlwl qu' => ['0' '0' '0' ... '1' '1' '0']
# ' warne shock australia epic collapse trent bridge johannesburg legendary australian lwwojxttiv' => ['0' '0' '0' ... '1' '1' '0']
# '   whippenz -PRON- horse rt sign petition stand voice -PRON- gilbert lncvu' => ['0' '0' '0' ... '1' '1' '0']
# ' nigerian military rescue hostage boko haram florida sentinel bulletin florid kctigymahl security terrorism' => ['0' '0' '0' ... '1' '1' '0']
# '   -PRON- love surely -PRON- blaze wild fire singe -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' slain mexican journalist unknowingly predict -PRON- death qxhowcv breitbartnew' => ['0' '0' '0' ... '1' '1' '0']
# ' china stock market crash gem rubble ox qb lwq foqjzw tg fqc zey' => ['0' '0' '0' ... '1' '1' '0']
# '   jewhaditm -PRON- amazing suicide bombing idea' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- ww siren fun dull bc ww siren monotonous' => ['0' '0' '0' ... '1' '1' '0']
# ' ginga -PRON- defeat -PRON- -PRON- drago destroy -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' learn legacy catastrophic eruption yorker vmwtouyohm' => ['0' '0' '0' ... '1' '1' '0']
# '   phdsquare mufc -PRON- build hype acquisition doubt -PRON- epl ablaze season' => ['0' '0' '0' ... '1' '1' '0']
# '   equipment ego break dig -PRON- family internet hoke sink term dfljev' => ['0' '0' '0' ... '1' '1' '0']
# ' business sponge dock wash flooding pmikavykl' => ['0' '0' '0' ... '1' '1' '0']
# '   myanmar displace rohingya sittwe cgf fpmr prison genocide ihhen msf refugee' => ['0' '0' '0' ... '1' '1' '0']
# '   question circle epicentre dspws hj' => ['0' '0' '0' ... '1' '1' '0']
# '   add sandy responder lose -PRON- vip vimeo lkxi uxjaq' => ['0' '0' '0' ... '1' '1' '0']
# ' naaa bee dead legit zombie sore -PRON- body fsdpfa' => ['0' '0' '0' ... '1' '1' '0']
# ' witness explode burn building st afternoon manchester cgmjlseylo mikecroninwmur' => ['0' '0' '0' ... '1' '1' '0']
# ' september defeater epicentre hell yeaahh' => ['0' '0' '0' ... '1' '1' '0']
# ' drown caitlin kiernan centipede press sign limit mcsek hx iifgaz fil' => ['0' '0' '0' ... '1' '1' '0']
# '   asukager magical bag blazing' => ['0' '0' '0' ... '1' '1' '0']
# '   heyitsepark heavy hail' => ['0' '0' '0' ... '1' '1' '0']
# ' dazzle destroy fun' => ['0' '0' '0' ... '1' '1' '0']
# ' survive -PRON-' => ['0' '0' '0' ... '1' '1' '0']
# ' hobbit desolation smaug thranduil scale action figure loose mirkwood nyel buaro zgiupn' => ['0' '0' '0' ... '1' '1' '0']
# ' bomb -PRON- family jamaicans love shout bullet' => ['0' '0' '0' ... '1' '1' '0']
# ' woman gps app rescuer injure biker marin county uojy sv' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- sit -PRON- ass scream -PRON- mother pull -PRON- grow tf' => ['0' '0' '0' ... '1' '1' '0']
# ' california police officer pull gun apparent provocation lhw vtbhzg dailykos' => ['0' '0' '0' ... '1' '1' '0']
# '   tadhgtgmtel dude smoke fucking flame bomb omg scared' => ['0' '0' '0' ... '1' '1' '0']
# ' omfg wake' => ['0' '0' '0' ... '1' '1' '0']
# ' pick flattened hay masonite wahpeton kw vq nijq' => ['0' '0' '0' ... '1' '1' '0']
# '   arianagrande justinbieber omgggg -PRON- screaming' => ['0' '0' '0' ... '1' '1' '0']
# ' politifiact harry reid percent woman serve plan parenthood claim pant fire lie amymwwcpym tcot' => ['0' '0' '0' ... '1' '1' '0']
# '   ring fort demolish pxpoqktjo' => ['0' '0' '0' ... '1' '1' '0']
# '   earthquake sicily italy iphone user download earthquake app azwoamzk' => ['0' '0' '0' ... '1' '1' '0']
# ' -PRON- girlfriend gorgeous woman crush ycwaulqz' => ['0' '0' '0' ... '1' '1' '0']
# '   treyarch davidvonderhaar bring demolition quarter' => ['0' '0' '0' ... '1' '1' '0']
# ' mh victim family furious medium wreckage confirmation carmqivkwu' => ['0' '0' '0' ... '1' '1' '0']
# ' escape engulf flame parley canyon crew ldgwsyowss cnyvvy wat' => ['0' '0' '0' ... '1' '1' '0']
# ' lightning fire vancouver island vdiliicyr' => ['0' '0' '0' ... '1' '1' '0']
# ' catastrophic hiroshima nagasaki atomic bombing ou chznq' => ['0' '0' '0' ... '1' '1' '0']
# '   hearitfrompatty pls -PRON- -PRON- campaign warn hazardous keratin treatment brazilian blowout copycat' => ['0' '0' '0' ... '1' '1' '0']
# '   heyimbeeyt -PRON- fire -PRON- skin -PRON- drown' => ['0' '0' '0' ... '1' '1' '0']
# ' plan lady wife president goodluck jonathan dame patience jonathan hijack hashgqafic' => ['0' '0' '0' ... '1' '1' '0']
# ' investigator fatal virgin galactic spaceship crash structural failure bgrab lk' => ['0' '0' '0' ... '1' '1' '0']
# ' tube strike travel update london engulf chaos cross london travel accepte vg hrbebda' => ['0' '0' '0' ... '1' '1' '0']
# '   nursing alert emergency psychiatric rn fte providence health olympia wa yu nue gfb' => ['0' '0' '0' ... '1' '1' '0']
# ' cont sinjar refer pg document movt yazidi hostage massacre' => ['0' '0' '0' ... '1' '1' '0']
# ' natural disaster urgent lfzhxn jakartapost' => ['0' '0' '0' ... '1' '1' '0']
# ' family sue legionnaire family affect fatal outbreak legionnaire disea vbsj tniv' => ['0' '0' '0' ... '1' '1' '0']
# '   blizzheroe love diablo map westmarch mt arreat pandemonium' => ['0' '0' '0' ... '1' '1' '0']
# ' morgan silver dollar gem bu dmpl cameo rev blaze grade iu bafdxey aphqu svet' => ['0' '0' '0' ... '1' '1' '0']

# %% [markdown]
# ## Same, but using Pipeline

# %%
# Many fitters can be passed, but the last parameter MUST BE a classifier
from sklearn.pipeline import Pipeline
text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='word',binary=True)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultinomialNB(alpha=1)),
])

# %%
text_clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=True,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('clf',
#                  MultinomialNB(alpha=1, class_prior=None, fit_prior=True))],
#          verbose=False)

# %% [markdown]
# ## PERFORMANCE

# %% [markdown]
# ### With MultinomialNaiveBayes

# %%
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
docs_test = X_test
predicted_MNB = text_clf.predict(docs_test)
metrics.accuracy_score(y_test,predicted_MNB)
# Out:
# 0.8102429415627052

# %% [markdown]
# ### With SDG Classifier

# %%
# SDG Classifier, no TF-IDF
# GridSearch states that TF-IDF=False is better
text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='word',binary=True)),
    ('clf', SGDClassifier(loss='hinge', penalty='l2',
                          alpha=0.01, random_state=42,
                          max_iter=5, tol=None)),
])

text_clf.fit(X_train, y_train)
docs_test = X_test
predicted_SGDC = text_clf.predict(docs_test)
metrics.accuracy_score(y_test,predicted_SGDC)
# Out:
# 0.7741300065659882

# %% [markdown]
# ### With Logistic Regression

# %%
# LR Classifier, no TF-IDF
# GridSearch states that TF-IDF=False is better
text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='word',binary=True)),
    ('clf', LogisticRegression()),
])

text_clf.fit(X_train, y_train)
docs_test = X_test
predicted_LR = text_clf.predict(docs_test)
metrics.accuracy_score(y_test,predicted_LR)
# Out:
# 0.8187787261982928

# %% [markdown]
# ## ALL Classifiers: Scores

# %%
def runClassifiers(X_train, y_train, X_test):
    classifiers =[LogisticRegression(), MultinomialNB(),DecisionTreeClassifier(),
        KNeighborsClassifier(),RandomForestClassifier(), SGDClassifier()]
    classifier_names = ['Logistic Regression','MultinomialNB','Decision-Tree Classfier','K-Neighbors Classifier',
                       'Random-Forest Classifier','SGDC Classifier']
    i=-1
    for classifier in classifiers:
        i = i + 1
        text_clf = Pipeline([
        ('vect', CountVectorizer(analyzer='word',binary=True)),#('tfidf', TfidfTransformer()),
        ('actualClassifier',classifier )])
        text_clf.fit(X_train, y_train)
        docs_test = X_test
        predicted = text_clf.predict(docs_test)
        print(classifier_names[i],np.mean(predicted == y_test))

# %%
runClassifiers(X_train, y_train, X_test)
# Out:
# Logistic Regression 0.8187787261982928
# MultinomialNB 0.8049901510177282
# Decision-Tree Classfier 0.7636244254760342
# K-Neighbors Classifier 0.6913985554826001
# Random-Forest Classifier 0.7898883782009193
# SGDC Classifier 0.7964543663821405

# %% [markdown]
# # GRID SEARCH

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
    'vect__ngram_range': [(1, 1), (1, 2),(1, 3)],
    'tfidf__use_idf': (True, False),
    'clf__alpha': (1e-2, 1e-3),
}

# %% [markdown]
# ### SGDClassifier

# %%
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(loss='hinge', penalty='l2',
                          alpha=1e-3, random_state=42,
                          max_iter=5, tol=None)),
])

# %%
gs_clf = GridSearchCV(text_clf, parameters, cv=5, n_jobs=-1)

# %%
gs_clf = gs_clf.fit(X_train, y_train)

# %%
print('Best Score: ',gs_clf.best_score_)
# Out:
# Best Score:  0.7689655172413794

# %%
print('SGDC Classifier')
for param_name in sorted(parameters.keys()):
    print("   %s: %r" % (param_name, gs_clf.best_params_[param_name]))
# Out:
# SGDC Classifier
#    clf__alpha: 0.01
#    tfidf__use_idf: False
#    vect__ngram_range: (1, 2)

# %% [markdown]
# # LOGISTIC REGRESSION - ON TOTAL TRAIN AND REAL TEST

# %%
X = train.text.values.astype('U')
y = train.target.values.astype('U')

# %%
# LR Classifier, no TF-IDF
# GridSearch states that TF-IDF=False is better
text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='word',binary=True)),
    ('clf', LogisticRegression()),
])

# %%
text_clf.fit(X, y)
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=True,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('clf',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
test  = pd.read_csv("csv_lio/test_clean.csv")
test  = test.drop(columns = 'Unnamed: 0')

# %%
predicted_LR = text_clf.predict(test.text.values.astype('U'))
predicted_LR
# Out:
# array(['0', '1', '1', ..., '1', '1', '0'], dtype='<U21')

# %%
sample_submission = pd.read_csv('original_data/sample_submission.csv')

# %%
sample_submission.target = predicted_LR
sample_submission = sample_submission.set_index('id')

# %%
sample_submission.head()
# Out:
#    target
# id
# 0       0
# 2       1
# 3       1
# 9       1
# 11      1

# %%
sample_submission.to_csv('pepito_cibrian_reloaded.csv')
